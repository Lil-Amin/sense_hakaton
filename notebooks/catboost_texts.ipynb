# %% [markdown]
# ### Import libraries

# %%
from catboost import CatBoostClassifier
import numpy as np
import pandas as pd
import os
import random
from sklearn.model_selection import GroupKFold
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
def SeedEverything(seed=808):
    """Method to seed everything."""
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)

# %%
def data_preprocessing(path="case_2_results.csv"):
    df = pd.read_csv(path)
    
    # Filling nans with spaces
    df['resume_main_keywords'] = df['resume_main_keywords'].fillna("")
    df['vacancy_main_keywords'] = df['vacancy_main_keywords'].fillna("")
    
    df['vacancy_description'] = df['vacancy_description'].fillna("")
    df['resume_description'] = df['resume_description'].fillna("")
    
    return df

# %% [markdown]
# ### Main part

# %%
SeedEverything()

# %%
df = data_preprocessing(path="case_2_results_new.csv")

# %%
df.head()
# Out:
#                              vacancy_id                             resume_id  \
# 0  779f3a59-206a-3241-adc4-d7db504f960b  74392e00-ecfb-335b-9fc1-c2652dca06e5
# 1  779f3a59-206a-3241-adc4-d7db504f960b  2b5ad5e1-1f31-3f3f-8a66-43cd89233672
# 2  779f3a59-206a-3241-adc4-d7db504f960b  ea1ac51a-e16b-367a-9216-52fb64809db1
# 3  779f3a59-206a-3241-adc4-d7db504f960b  ecfc02a1-592c-3ed0-a801-1ad9ab3d30b8
# 4  779f3a59-206a-3241-adc4-d7db504f960b  aff6b6bd-89c2-3b2c-ab2e-0b9f76ac367c
#
#    requested_experience                                vacancy_description  \
# 0                   3.0   описание мы расширяем команды и ищем разработ...
# 1                   3.0   описание мы расширяем команды и ищем разработ...
# 2                   3.0   описание мы расширяем команды и ищем разработ...
# 3                   3.0   описание мы расширяем команды и ищем разработ...
# 4                   3.0   описание мы расширяем команды и ищем разработ...
#
#                                   resume_description  is_english  \
# 0   интеграционные адаптеры для передачи заявок п...       False
# 1   разработка программного комплекса кредитного ...       False
# 2   • разрабатывал backend часть по открытию, зак...        True
# 3  full architecture & design & release & support...        True
# 4   разработка сервиса с нуля. spring boot + post...        True
#
#              edu  target  resume_experience  \
# 0  relevant_high   False                 10
# 1  relevant_high   False                  9
# 2  relevant_high   False                  4
# 3  relevant_high   False                 13
# 4  relevant_high   False                  5
#
#                  vacancy_main_keywords  \
# 0  java разработчик команда инвестиции
# 1  java разработчик команда инвестиции
# 2  java разработчик команда инвестиции
# 3  java разработчик команда инвестиции
# 4  java разработчик команда инвестиции
#
#                                 resume_main_keywords
# 0  java spring boot java ee sql hibernate git doc...
# 1  ооп java java spring framework kotlin mysql do...
# 2  java spring framework hibernate orm sql java j...
# 3  java git sql html javascript css mysql ооп lin...
# 4  java spring git postgresql hibernate orm bpmn ...

# %% [markdown]
# ### Create kfold object

# %%
# Define groups based on 'vacancy_id'
groups = df['vacancy_id']

# Initialize GroupKFold
gkf = GroupKFold(n_splits=5)

# %% [markdown]
# ### Create catboost model

# %%
# Initialize CatBoost classifier
model = CatBoostClassifier(loss_function='Logloss', eval_metric='F1', depth=3, iterations=200, learning_rate=0.15)

# Specify categorical features
cat_features = ['is_english', 'edu',]

# Specify text features
text_features = ['vacancy_main_keywords', 'resume_main_keywords', 'vacancy_description'] # 'vacancy_description'

# %% [markdown]
# ### Train catboost and check precision score

# %%
f1_scores = []
score = 0
fold = 0

# Iterate over splits
for train_idx, val_idx in gkf.split(df, df['target'], groups=groups):
    train_df = df.iloc[train_idx]
    val_df = df.iloc[val_idx]

    # Train the model
    model.fit(
        train_df.drop(columns=['target', 'vacancy_id', 'resume_id', 'resume_description']), train_df['target'],
        cat_features=cat_features,
        text_features=text_features,
        eval_set=(val_df.drop(columns=['target', 'vacancy_id', 'resume_id', 'resume_description']), val_df['target']),
        verbose=10,
        use_best_model=False,
    )
    
    # Make predictions on the validation set
    val_preds = model.predict(val_df.drop(columns=['target', 'vacancy_id', 'resume_id', 'resume_description']))
    # Convert predicted labels to boolean values
    val_preds = val_preds == 'True'
    # Calculate precision for the current fold and append it to the list
    f1 = f1_score(val_df['target'], val_preds)
    
    # Save score
    f1_scores.append(f1)
    score += f1
    
    # Specify the file path where you want to save the model
    model_path = f'catboost_model_fold_new_{fold}.cbm'
    fold += 1
    # Save the model to the specified file path
    model.save_model(model_path)
    
    

print("############")
print(f"Average f1 score for {gkf.n_splits} splits:", score / gkf.n_splits)
# Out:
# 0:	learn: 0.7146067	test: 0.4923077	best: 0.4923077 (0)	total: 31.4ms	remaining: 6.25s
# 10:	learn: 0.7365439	test: 0.5185185	best: 0.5185185 (3)	total: 341ms	remaining: 5.86s
# 20:	learn: 0.7808989	test: 0.5185185	best: 0.5185185 (3)	total: 650ms	remaining: 5.54s
# 30:	learn: 0.7877095	test: 0.5185185	best: 0.5185185 (3)	total: 961ms	remaining: 5.24s
# 40:	learn: 0.7966102	test: 0.5283019	best: 0.5283019 (36)	total: 1.27s	remaining: 4.92s
# 50:	learn: 0.8225352	test: 0.5283019	best: 0.5283019 (36)	total: 1.58s	remaining: 4.62s
# 60:	learn: 0.8441926	test: 0.5000000	best: 0.5283019 (36)	total: 1.89s	remaining: 4.3s
# 70:	learn: 0.8563380	test: 0.5283019	best: 0.5283019 (36)	total: 2.2s	remaining: 3.99s
# 80:	learn: 0.8876081	test: 0.5660377	best: 0.5660377 (80)	total: 2.5s	remaining: 3.68s
# 90:	learn: 0.8979592	test: 0.5283019	best: 0.5660377 (80)	total: 2.81s	remaining: 3.37s
# 100:	learn: 0.8953488	test: 0.5454545	best: 0.5660377 (80)	total: 3.13s	remaining: 3.07s
# 110:	learn: 0.9154519	test: 0.5555556	best: 0.5660377 (80)	total: 3.44s	remaining: 2.76s
# 120:	learn: 0.9208211	test: 0.5660377	best: 0.5660377 (80)	total: 3.75s	remaining: 2.45s
# 130:	learn: 0.9321534	test: 0.5818182	best: 0.5925926 (128)	total: 4.06s	remaining: 2.14s
# 140:	learn: 0.9349112	test: 0.5818182	best: 0.5925926 (128)	total: 4.37s	remaining: 1.83s
# 150:	learn: 0.9345238	test: 0.5925926	best: 0.5925926 (128)	total: 4.68s	remaining: 1.52s
# 160:	learn: 0.9461078	test: 0.5925926	best: 0.5925926 (128)	total: 4.98s	remaining: 1.21s
# 170:	learn: 0.9461078	test: 0.5714286	best: 0.5925926 (128)	total: 5.29s	remaining: 898ms
# 180:	learn: 0.9546828	test: 0.5818182	best: 0.5925926 (128)	total: 5.6s	remaining: 588ms
# 190:	learn: 0.9489489	test: 0.5818182	best: 0.5925926 (128)	total: 5.91s	remaining: 279ms
# 199:	learn: 0.9520958	test: 0.5818182	best: 0.5925926 (128)	total: 6.19s	remaining: 0us
#
# bestTest = 0.5925925926
# bestIteration = 128
#
# 0:	learn: 0.6517857	test: 0.6666667	best: 0.6666667 (0)	total: 31.2ms	remaining: 6.2s
# 10:	learn: 0.5321888	test: 0.1025641	best: 0.6666667 (0)	total: 341ms	remaining: 5.85s
# 20:	learn: 0.6934307	test: 0.1000000	best: 0.6666667 (0)	total: 649ms	remaining: 5.54s
# 30:	learn: 0.7464789	test: 0.1860465	best: 0.6666667 (0)	total: 956ms	remaining: 5.21s
# 40:	learn: 0.7811448	test: 0.6666667	best: 0.6666667 (0)	total: 1.27s	remaining: 4.91s
# 50:	learn: 0.8078176	test: 0.6129032	best: 0.6865672 (44)	total: 1.57s	remaining: 4.6s
# 60:	learn: 0.8208469	test: 0.6250000	best: 0.7058824 (58)	total: 1.89s	remaining: 4.3s
# 70:	learn: 0.8543689	test: 0.6250000	best: 0.7058824 (58)	total: 2.19s	remaining: 3.98s
# 80:	learn: 0.8617363	test: 0.6984127	best: 0.7058824 (58)	total: 2.5s	remaining: 3.68s
# 90:	learn: 0.8753994	test: 0.6984127	best: 0.7058824 (58)	total: 2.93s	remaining: 3.51s
# 100:	learn: 0.8910256	test: 0.7301587	best: 0.7301587 (100)	total: 3.55s	remaining: 3.48s
# 110:	learn: 0.9009585	test: 0.7301587	best: 0.7301587 (100)	total: 3.92s	remaining: 3.15s
# 120:	learn: 0.9308176	test: 0.7096774	best: 0.7301587 (100)	total: 4.23s	remaining: 2.76s
# 130:	learn: 0.9240506	test: 0.7301587	best: 0.7301587 (100)	total: 4.54s	remaining: 2.39s
# 140:	learn: 0.9367089	test: 0.7301587	best: 0.7419355 (137)	total: 4.85s	remaining: 2.03s
# 150:	learn: 0.9396825	test: 0.7500000	best: 0.7500000 (150)	total: 5.16s	remaining: 1.67s
# 160:	learn: 0.9396825	test: 0.7272727	best: 0.7500000 (150)	total: 5.47s	remaining: 1.32s
# 170:	learn: 0.9493671	test: 0.7272727	best: 0.7500000 (150)	total: 5.78s	remaining: 980ms
# 180:	learn: 0.9556962	test: 0.7272727	best: 0.7500000 (150)	total: 6.08s	remaining: 639ms
# 190:	learn: 0.9617834	test: 0.7272727	best: 0.7500000 (150)	total: 6.4s	remaining: 302ms
# 199:	learn: 0.9556962	test: 0.7272727	best: 0.7500000 (150)	total: 6.67s	remaining: 0us
#
# bestTest = 0.75
# bestIteration = 150
#
# 0:	learn: 0.3582090	test: 0.3461538	best: 0.3461538 (0)	total: 31.5ms	remaining: 6.26s
# 10:	learn: 0.6024096	test: 0.5600000	best: 0.6486486 (1)	total: 344ms	remaining: 5.91s
# 20:	learn: 0.6762590	test: 0.6516854	best: 0.6516854 (17)	total: 658ms	remaining: 5.61s
# 30:	learn: 0.7508532	test: 0.6947368	best: 0.6947368 (30)	total: 970ms	remaining: 5.29s
# 40:	learn: 0.7868852	test: 0.6881720	best: 0.7096774 (36)	total: 1.28s	remaining: 4.96s
# 50:	learn: 0.8376623	test: 0.7252747	best: 0.7252747 (49)	total: 1.59s	remaining: 4.65s
# 60:	learn: 0.8534202	test: 0.7111111	best: 0.7252747 (49)	total: 1.9s	remaining: 4.34s
# 70:	learn: 0.8636364	test: 0.6744186	best: 0.7252747 (49)	total: 2.22s	remaining: 4.03s
# 80:	learn: 0.8903226	test: 0.6896552	best: 0.7252747 (49)	total: 2.53s	remaining: 3.71s
# 90:	learn: 0.8974359	test: 0.6976744	best: 0.7252747 (49)	total: 2.84s	remaining: 3.4s
# 100:	learn: 0.9067524	test: 0.6976744	best: 0.7252747 (49)	total: 3.15s	remaining: 3.09s
# 110:	learn: 0.9290323	test: 0.7142857	best: 0.7252747 (49)	total: 3.46s	remaining: 2.78s
# 120:	learn: 0.9290323	test: 0.7058824	best: 0.7252747 (49)	total: 3.77s	remaining: 2.46s
# 130:	learn: 0.9324759	test: 0.7058824	best: 0.7252747 (49)	total: 4.08s	remaining: 2.15s
# 140:	learn: 0.9385113	test: 0.7058824	best: 0.7252747 (49)	total: 4.39s	remaining: 1.84s
# 150:	learn: 0.9446254	test: 0.7058824	best: 0.7252747 (49)	total: 4.7s	remaining: 1.53s
# 160:	learn: 0.9480519	test: 0.7058824	best: 0.7252747 (49)	total: 5.01s	remaining: 1.21s
# 170:	learn: 0.9511401	test: 0.7142857	best: 0.7252747 (49)	total: 5.33s	remaining: 903ms
# 180:	learn: 0.9511401	test: 0.6987952	best: 0.7252747 (49)	total: 5.64s	remaining: 592ms
# 190:	learn: 0.9545455	test: 0.6987952	best: 0.7252747 (49)	total: 5.96s	remaining: 281ms
# 199:	learn: 0.9545455	test: 0.7142857	best: 0.7252747 (49)	total: 6.24s	remaining: 0us
#
# bestTest = 0.7252747253
# bestIteration = 49
#
# 0:	learn: 0.6127946	test: 0.7241379	best: 0.7241379 (0)	total: 31.9ms	remaining: 6.35s
# 10:	learn: 0.6034483	test: 0.4473684	best: 0.7241379 (0)	total: 351ms	remaining: 6.03s
# 20:	learn: 0.6694215	test: 0.5185185	best: 0.7241379 (0)	total: 667ms	remaining: 5.69s
# 30:	learn: 0.7068273	test: 0.4871795	best: 0.7241379 (0)	total: 982ms	remaining: 5.35s
# 40:	learn: 0.7432950	test: 0.4615385	best: 0.7241379 (0)	total: 1.3s	remaining: 5.03s
# 50:	learn: 0.7896679	test: 0.5185185	best: 0.7241379 (0)	total: 1.61s	remaining: 4.71s
# 60:	learn: 0.8273381	test: 0.6530612	best: 0.7241379 (0)	total: 1.93s	remaining: 4.4s
# 70:	learn: 0.8592058	test: 0.6595745	best: 0.7241379 (0)	total: 2.25s	remaining: 4.08s
# 80:	learn: 0.8840580	test: 0.6808511	best: 0.7241379 (0)	total: 2.56s	remaining: 3.77s
# 90:	learn: 0.9032258	test: 0.6593407	best: 0.7241379 (0)	total: 2.88s	remaining: 3.45s
# 100:	learn: 0.9136691	test: 0.6516854	best: 0.7241379 (0)	total: 3.19s	remaining: 3.13s
# 110:	learn: 0.9136691	test: 0.6739130	best: 0.7241379 (0)	total: 3.51s	remaining: 2.81s
# 120:	learn: 0.9175627	test: 0.7083333	best: 0.7241379 (0)	total: 3.83s	remaining: 2.5s
# 130:	learn: 0.9142857	test: 0.6947368	best: 0.7241379 (0)	total: 4.14s	remaining: 2.18s
# 140:	learn: 0.9214286	test: 0.7021277	best: 0.7241379 (0)	total: 4.46s	remaining: 1.86s
# 150:	learn: 0.9252669	test: 0.7157895	best: 0.7241379 (0)	total: 4.77s	remaining: 1.55s
# 160:	learn: 0.9290780	test: 0.7216495	best: 0.7241379 (0)	total: 5.09s	remaining: 1.23s
# 170:	learn: 0.9323843	test: 0.7157895	best: 0.7241379 (0)	total: 5.4s	remaining: 917ms
# 180:	learn: 0.9357143	test: 0.7083333	best: 0.7241379 (0)	total: 5.72s	remaining: 601ms
# 190:	learn: 0.9395018	test: 0.7083333	best: 0.7241379 (0)	total: 6.04s	remaining: 284ms
# 199:	learn: 0.9469965	test: 0.7083333	best: 0.7241379 (0)	total: 6.32s	remaining: 0us
#
# bestTest = 0.724137931
# bestIteration = 0
#
# 0:	learn: 0.7025641	test: 0.6333333	best: 0.6333333 (0)	total: 31.9ms	remaining: 6.34s
# 10:	learn: 0.7409836	test: 0.5384615	best: 0.6333333 (0)	total: 347ms	remaining: 5.95s
# 20:	learn: 0.7285223	test: 0.4864865	best: 0.6333333 (0)	total: 662ms	remaining: 5.64s
# 30:	learn: 0.7574751	test: 0.4878049	best: 0.6333333 (0)	total: 978ms	remaining: 5.33s
# 40:	learn: 0.8026316	test: 0.5783133	best: 0.6333333 (0)	total: 1.29s	remaining: 5.01s
# 50:	learn: 0.8250825	test: 0.5789474	best: 0.6333333 (0)	total: 1.6s	remaining: 4.69s
# 60:	learn: 0.8506494	test: 0.6588235	best: 0.6588235 (58)	total: 1.92s	remaining: 4.37s
# 70:	learn: 0.8753994	test: 0.5974026	best: 0.6666667 (62)	total: 2.24s	remaining: 4.07s
# 80:	learn: 0.8817891	test: 0.6744186	best: 0.6744186 (77)	total: 2.55s	remaining: 3.75s
# 90:	learn: 0.9003215	test: 0.6419753	best: 0.6744186 (77)	total: 2.87s	remaining: 3.43s
# 100:	learn: 0.8967742	test: 0.6097561	best: 0.6744186 (77)	total: 3.18s	remaining: 3.12s
# 110:	learn: 0.8996764	test: 0.6516854	best: 0.6744186 (77)	total: 3.5s	remaining: 2.8s
# 120:	learn: 0.9185668	test: 0.6436782	best: 0.6744186 (77)	total: 3.81s	remaining: 2.49s
# 130:	learn: 0.9220779	test: 0.6428571	best: 0.6744186 (77)	total: 4.12s	remaining: 2.17s
# 140:	learn: 0.9225806	test: 0.6352941	best: 0.6744186 (77)	total: 4.44s	remaining: 1.86s
# 150:	learn: 0.9320388	test: 0.6097561	best: 0.6744186 (77)	total: 4.75s	remaining: 1.54s
# 160:	learn: 0.9350649	test: 0.6172840	best: 0.6744186 (77)	total: 5.06s	remaining: 1.23s
# 170:	learn: 0.9442623	test: 0.6190476	best: 0.6744186 (77)	total: 5.38s	remaining: 912ms
# 180:	learn: 0.9511401	test: 0.6190476	best: 0.6744186 (77)	total: 5.69s	remaining: 598ms
# 190:	learn: 0.9576547	test: 0.6265060	best: 0.6744186 (77)	total: 6.01s	remaining: 283ms
# 199:	learn: 0.9545455	test: 0.6265060	best: 0.6744186 (77)	total: 6.29s	remaining: 0us
#
# bestTest = 0.6744186047
# bestIteration = 77
#
# ############
# Average f1 score for 5 splits: 0.6716431961612684

# %% [markdown]
# ### Inference

# %%
df = data_preprocessing(path="case_2_test_new.csv")

# %%
NUM_MODELS = 5

# %%
for fold in range(0, NUM_MODELS):
    # Specify the file path from which you want to load the model
    model_path = f'catboost_model_fold_new_{fold}.cbm'
    
    # Load the model from the specified file path
    inference_model = CatBoostClassifier()
    inference_model.load_model(model_path)
    
    # Make predictions on the validation set
    preds_proba = model.predict_proba(df.drop(columns=['target', 'vacancy_id', 'resume_id', 'resume_description']))
    
    if fold == 0:
        preds_proba_total = preds_proba
    else:
        preds_proba_total += preds_proba
    
preds_proba_total = preds_proba_total / NUM_MODELS

# %%
# Process probabilities
preds = preds_proba_total[:, 1]
preds = preds > 0.5

# %%
# Save submission in csv format
df["model_preds"] = preds
df.to_csv("submission.csv", index=False)
